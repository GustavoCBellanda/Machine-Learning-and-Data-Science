# %% [markdown]
# Accuracy = 84,52%

# %%
from sklearn.neural_network import MLPClassifier

# %%
import pickle
with open('./Machine Learning e Data Science com Python de A à Z/Bases de dados/census.pkl', 'rb') as f:
    x_census_treinamento, y_census_treinamento, x_census_teste, y_census_teste = pickle.load(f)

# %%
x_census_treinamento.shape, y_census_treinamento.shape
# Out:
# ((27676, 108), (27676,))

# %%
x_census_teste.shape, y_census_teste.shape
# Out:
# ((4885, 108), (4885,))

# %%
neural_network_census = MLPClassifier(max_iter=2500, verbose=True, tol=0.00001, 
                            solver = 'adam', activation = 'relu', hidden_layer_sizes = (55, 55))
neural_network_census.fit(x_census_treinamento, y_census_treinamento)
# Out:
# Iteration 1, loss = 0.38875864
# Iteration 2, loss = 0.32842108
# Iteration 3, loss = 0.31552891
# Iteration 4, loss = 0.30839753
# Iteration 5, loss = 0.30348232
# Iteration 6, loss = 0.29932416
# Iteration 7, loss = 0.29569561
# Iteration 8, loss = 0.29255548
# Iteration 9, loss = 0.29039873
# Iteration 10, loss = 0.28810262
# Iteration 11, loss = 0.28643659
# Iteration 12, loss = 0.28394189
# Iteration 13, loss = 0.28138228
# Iteration 14, loss = 0.28008185
# Iteration 15, loss = 0.27841717
# Iteration 16, loss = 0.27632171
# Iteration 17, loss = 0.27405574
# Iteration 18, loss = 0.27304193
# Iteration 19, loss = 0.27116975
# Iteration 20, loss = 0.27066743
# Iteration 21, loss = 0.26784769
# Iteration 22, loss = 0.26678361
# Iteration 23, loss = 0.26458430
# Iteration 24, loss = 0.26357466
# Iteration 25, loss = 0.26141862
# Iteration 26, loss = 0.26022786
# Iteration 27, loss = 0.25950246
# Iteration 28, loss = 0.25709628
# Iteration 29, loss = 0.25570806
# ...

# %%
previsoes = neural_network_census.predict(x_census_teste)
previsoes
# Out:
# array([' <=50K', ' <=50K', ' <=50K', ..., ' <=50K', ' <=50K', ' >50K'],
#       dtype='<U6')

# %%
y_census_teste
# Out:
# array([' <=50K', ' <=50K', ' <=50K', ..., ' <=50K', ' <=50K', ' <=50K'],
#       dtype=object)

# %%
from sklearn.metrics import accuracy_score, classification_report
accuracy_score(y_census_teste, previsoes)
# Out:
# 0.8452405322415558
